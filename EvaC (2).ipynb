# %% [markdown]
# # <font color = 'pink' > Eva's Expertice <3

# %% [markdown]
# ![frog](https://media1.giphy.com/media/6FxJBpNTBgWdJCXKD4/giphy.gif?cid=ecf05e47xm0d4ovzklj7tjsjzgqp9ijbee8rt7g5yes00jnr&rid=giphy.gif&ct=g)
#
# ## <font color = 'purple' > Introduction:
# We will be taking a look at the Pittsburgh Police Arrest Data and counting the number of arrests per neighborhood
#
# ## <font color = 'purple' > The Metric:
# Our metric is the safest neighborhood, so the lowest amount of arrests will be awarded the safest neighborhood in this category. Here is the first 10 arrests and their information below:

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

arrest = pd.read_csv("arrest.csv")
arrest.head(10)
# Out:
#         PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# 5  1974556  16144301  45.0      M    W  2016-08-15T13:30:00
# 6  1974628  16147655  29.0      M    W  2016-08-16T13:00:00
# 7  1974607  16146037  21.0      F    B  2016-08-16T04:25:00
# 8  1974643  16132537  17.0      M    B  2016-08-29T17:55:00
# 9  1974647  16138646  14.0      M    B  2016-08-23T13:36:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# ...

# %% [markdown]
# As we said earlier, we are looking at which neighborhood has the fewest arrests, so we will be looking under the INCIDENTNEIGHBORHOOD column and counting each instance of a neighborhood up to identify the neighborhood with the fewest arrest numbers.

# %%
a = arrest['INCIDENTNEIGHBORHOOD'].value_counts()
print(a)
# Out:
# Central Business District    3790
# South Side Flats             3190
# Carrick                      2199
# East Allegheny               2017
# Homewood South               1944
#                              ...
# Ridgemont                      35
# Central Northside              23
# Mt. Oliver Boro                18
# Troy Hill-Herrs Island          6
# Mt. Oliver Neighborhood         2
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %% [markdown]
# Now lets make some graphs!

# %%
arr = arrest['INCIDENTNEIGHBORHOOD']
arr = arrest['INCIDENTNEIGHBORHOOD'].value_counts().rename_axis("neighborhood").to_frame(name='arrests')
print(arr)
# Out:
#                            arrests
# neighborhood
# Central Business District     3790
# South Side Flats              3190
# Carrick                       2199
# East Allegheny                2017
# Homewood South                1944
# ...                            ...
# Ridgemont                       35
# Central Northside               23
# Mt. Oliver Boro                 18
# Troy Hill-Herrs Island           6
# Mt. Oliver Neighborhood          2
#
# [98 rows x 1 columns]

# %% [markdown]
# Now lets take a look at a graph of the bottom few neighborhoods when it comes to arrests, to determine which has the least amount of arrests.

# %%
bottom_graph = arr.iloc[78:]


bottom_graph.plot.bar(title='Arrests in Neighborhoods in Pittsburgh')
plt.xlabel("Neighborhood")
plt.ylabel("Arrests")
# Out:
# Text(0, 0.5, 'Arrests')

# %% [markdown]
# ## <font color = 'purple' > The Best Neighborhood!!
# Based on this information alone, Mt. Oliver Neighborhood is the safest neighborhood.

# %% [markdown]
# Now we will take a look at all other data combined (arrests, crashes, and deaths) to determine the safest neighborhood in Pittsburgh
